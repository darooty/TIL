# %% [markdown]
# # Import Modules

# %%
import numpy as np
import pandas as pd
pd.set_option('max_columns', 90)
import matplotlib.pyplot as plt
import seaborn as sns
PALETTE = ['#dd4124','#009473', '#b4b4b4', '#336b87']
BACKCOLOR = '#f6f5f5'
sns.set_palette(PALETTE)

from scipy.stats import norm, probplot, skew
from scipy.special import boxcox1p
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, RobustScaler
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold, RepeatedStratifiedKFold
from sklearn.model_selection import RepeatedKFold, train_test_split, RandomizedSearchCV
from sklearn.neighbors import  KNeighborsClassifier as knn
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
import xgboost
from xgboost import XGBClassifier
from sklearn.metrics import auc, accuracy_score, confusion_matrix

from IPython.core.display import HTML

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 120
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False

# %% [markdown]
# # Read Data

# %%
# Import training and test data.
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# When exploring a dataset, it is recommended to use the entire data.
all_data = pd.concat((train, test)).reset_index(drop=True)

# %% [markdown]
# # Feature engineering

# %%
# missing values
all_data['Age'] = all_data.Age.fillna(train.Age.median())
all_data['Fare'] = all_data.Fare.fillna(train.Fare.median())
all_data.dropna(subset=['Embarked'], inplace=True)
cabins = all_data.Cabin
all_data.drop(['Cabin'], axis=1, inplace=True)

# %%
# derivative features
all_data['CabinCnt'] = cabins.apply(lambda x: 0 if pd.isna(x) else len(x.split(' ')))
all_data['CabinClass'] = cabins.apply(lambda x: str(x)[0])
all_data['IsNumericTicket'] = all_data.Ticket.apply(lambda x: 1 if x.isnumeric() else 0)
all_data['TicketType'] = all_data.Ticket.apply(lambda x: ''.join(x.split(' ')[:-1]).replace('.','').replace('/','').lower() if len(x.split(' ')[:-1]) > 0 else 0)
all_data['Title'] = all_data.Name.apply(lambda x: x.split(',')[1].split('.')[0].strip())
all_data['Family'] = all_data.SibSp + all_data.Parch

# %%
# feature transform
numeric_vars = ['Age', 'SibSp', 'Parch', 'Fare', 'CabinCnt', 'Family']
ordinal_vars = ['Pclass']
nominal_vars = ['Name', 'Sex', 'Ticket', 'Embarked', 'CabinClass', 'IsNumericTicket', 'TicketType', 'Title']
all_data[nominal_vars] = all_data[nominal_vars].astype('str')

for feature in numeric_vars:
    all_data[feature] = np.log1p(all_data[feature])

scaler = StandardScaler()
numeric_vars = all_data.columns[(all_data.dtypes != 'object') & (all_data.columns != 'PassengerId') & (all_data.columns != 'Survived') & (all_data.columns != 'IsTrain')]
all_data[numeric_vars] = scaler.fit_transform(all_data[numeric_vars])

# %%
# split data
all_data.drop(['PassengerId', 'Name', 'Ticket'], axis=1, inplace=True)
data_dummies = pd.get_dummies(all_data)
X_train = data_dummies[data_dummies.Survived.notnull()].drop(['Survived'], axis=1)
y_train = data_dummies[data_dummies.Survived.notnull()].Survived
X_test = data_dummies[data_dummies.Survived.isnull()].drop(['Survived'], axis=1)

# %%
X_train.shape, y_train.shape, X_test.shape
# Out:
# ((889, 76), (889,), (418, 76))

# %% [markdown]
# ## Modeling

# %%
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

# %%
sol = pd.read_csv('정답.csv')

# %% [markdown]
# ## 테스트1
# 그리드서치를 사용해서 best_estimator를 생성 후 테스트한 결과와 best_params를 사용해서 새로 모델 생성 후 학습(전체 데이터) -> 테스트한 결과가 같다.

# %%
model_lg = LogisticRegression()
param_lg = {
    'C': [.001, .0001, .01, .1, 1]
}
search_lg = GridSearchCV(model_lg, param_lg, cv=cv, scoring='roc_auc').fit(X_train, y_train)
cv_rlt_lg = pd.DataFrame(search_lg.cv_results_)

best_params_lg = search_lg.best_params_
best_estimator_lg = search_lg.best_estimator_
model_lg = LogisticRegression(**best_params_lg)

model_lg = model_lg.fit(X_train, y_train)
y_pred_model_lg = model_lg.predict(X_test)
y_pred_best_estimator_lg = best_estimator_lg.predict(X_test)

# %%
model_svm = SVC()
param_svm = {
    'C': [.001, .0001, .01, .1, 1],
    'gamma': [.001, .0001, .01, .1, 1]
}
search_svm = GridSearchCV(model_svm, param_svm, cv=cv, scoring='roc_auc', verbose=1).fit(X_train, y_train)
cv_rlt_svm = pd.DataFrame(search_svm.cv_results_)

best_params_svm = search_svm.best_params_
best_estimator_svm = search_svm.best_estimator_
model_svm = SVC(**best_params_svm)

model_svm = model_svm.fit(X_train, y_train)
y_pred_model_svm = model_svm.predict(X_test)
y_pred_best_estimator_svm = best_estimator_svm.predict(X_test)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits

# %%
xtrain, xvalid = train_test_split(X_train, test_size=0.2, random_state=42)
ytrain, yvalid = train_test_split(y_train, test_size=0.2, random_state=42)

# %%
model_xgb = XGBClassifier()
param_xgb = {
    'learning_rate': [.001, .01, 1, 10],
    'objective': ['binary:logistic'],
    'use_label_encoder': [False],
    'eval_metric': ['mlogloss'],
    'n_estimators': [1000]
}
search_xgb = GridSearchCV(model_xgb, param_xgb, cv=cv, verbose=1, scoring='roc_auc').fit(xtrain, ytrain, early_stopping_rounds=15,
                                                                      eval_metric=['logloss'], eval_set=[(xvalid, yvalid)]
                                                                     )
cv_rlt_xgb = pd.DataFrame(search_xgb.cv_results_)

best_params_xgb = search_xgb.best_params_
best_estimator_xgb = search_xgb.best_estimator_
model_xgb = XGBClassifier(**best_params_xgb)

model_xgb = model_xgb.fit(X_train, y_train)
y_pred_model_xgb = model_xgb.predict(X_test)
y_pred_best_estimator_xgb = best_estimator_xgb.predict(X_test)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [0]	validation_0-logloss:0.69268
# [1]	validation_0-logloss:0.69221
# [2]	validation_0-logloss:0.69174
# [3]	validation_0-logloss:0.69128
# [4]	validation_0-logloss:0.69082
# [5]	validation_0-logloss:0.69035
# [6]	validation_0-logloss:0.68990
# [7]	validation_0-logloss:0.68943
# [8]	validation_0-logloss:0.68897
# [9]	validation_0-logloss:0.68851
# [10]	validation_0-logloss:0.68806
# [11]	validation_0-logloss:0.68759
# [12]	validation_0-logloss:0.68713
# [13]	validation_0-logloss:0.68668
# [14]	validation_0-logloss:0.68623
# [15]	validation_0-logloss:0.68578
# [16]	validation_0-logloss:0.68532
# [17]	validation_0-logloss:0.68487
# [18]	validation_0-logloss:0.68442
# [19]	validation_0-logloss:0.68397
# [20]	validation_0-logloss:0.68352
# [21]	validation_0-logloss:0.68307
# [22]	validation_0-logloss:0.68263
# [23]	validation_0-logloss:0.68218
# [24]	validation_0-logloss:0.68173
# [25]	validation_0-logloss:0.68129
# [26]	validation_0-logloss:0.68085
# [27]	validation_0-logloss:0.68040
# [28]	validation_0-logloss:0.67996
# [29]	validation_0-logloss:0.67952
# [30]	validation_0-logloss:0.67908
# [31]	validation_0-logloss:0.67863
# [32]	validation_0-logloss:0.67818
# [33]	validation_0-logloss:0.67774
# [34]	validation_0-logloss:0.67730
# [35]	validation_0-logloss:0.67686
# [36]	validation_0-logloss:0.67642
# [37]	validation_0-logloss:0.67598
# [38]	validation_0-logloss:0.67555
# [39]	validation_0-logloss:0.67511
# [40]	validation_0-logloss:0.67467
# [41]	validation_0-logloss:0.67424
# [42]	validation_0-logloss:0.67380
# [43]	validation_0-logloss:0.67338
# [44]	validation_0-logloss:0.67295
# [45]	validation_0-logloss:0.67252
# [46]	validation_0-logloss:0.67209
# [47]	validation_0-logloss:0.67166
# [48]	validation_0-logloss:0.67124
# [49]	validation_0-logloss:0.67080
# [50]	validation_0-logloss:0.67038
# [51]	validation_0-logloss:0.66995
# [52]	validation_0-logloss:0.66953
# [53]	validation_0-logloss:0.66910
# [54]	validation_0-logloss:0.66869
# [55]	validation_0-logloss:0.66826
# [56]	validation_0-logloss:0.66783
# [57]	validation_0-logloss:0.66742
# [58]	validation_0-logloss:0.66700
# [59]	validation_0-logloss:0.66659
# [60]	validation_0-logloss:0.66617
# [61]	validation_0-logloss:0.66575
# [62]	validation_0-logloss:0.66533
# [63]	validation_0-logloss:0.66492
# [64]	validation_0-logloss:0.66451
# [65]	validation_0-logloss:0.66410
# [66]	validation_0-logloss:0.66368
# [67]	validation_0-logloss:0.66326
# [68]	validation_0-logloss:0.66285
# [69]	validation_0-logloss:0.66245
# [70]	validation_0-logloss:0.66204
# [71]	validation_0-logloss:0.66163
# [72]	validation_0-logloss:0.66122
# [73]	validation_0-logloss:0.66082
# [74]	validation_0-logloss:0.66040
# [75]	validation_0-logloss:0.66001
# [76]	validation_0-logloss:0.65959
# [77]	validation_0-logloss:0.65920
# [78]	validation_0-logloss:0.65880
# [79]	validation_0-logloss:0.65840
# [80]	validation_0-logloss:0.65799
# [81]	validation_0-logloss:0.65760
# [82]	validation_0-logloss:0.65719
# [83]	validation_0-logloss:0.65679
# [84]	validation_0-logloss:0.65639
# [85]	validation_0-logloss:0.65600
# [86]	validation_0-logloss:0.65560
# [87]	validation_0-logloss:0.65521
# [88]	validation_0-logloss:0.65481
# [89]	validation_0-logloss:0.65442
# [90]	validation_0-logloss:0.65401
# [91]	validation_0-logloss:0.65363
# [92]	validation_0-logloss:0.65323
# [93]	validation_0-logloss:0.65285
# [94]	validation_0-logloss:0.65246
# [95]	validation_0-logloss:0.65207
# [96]	validation_0-logloss:0.65167
# [97]	validation_0-logloss:0.65130
# [98]	validation_0-logloss:0.65091
# [99]	validation_0-logloss:0.65053
# [100]	validation_0-logloss:0.65013
# [101]	validation_0-logloss:0.64975
# [102]	validation_0-logloss:0.64936
# [103]	validation_0-logloss:0.64898
# [104]	validation_0-logloss:0.64860
# [105]	validation_0-logloss:0.64822
# [106]	validation_0-logloss:0.64784
# [107]	validation_0-logloss:0.64746
# [108]	validation_0-logloss:0.64707
# [109]	validation_0-logloss:0.64670
# [110]	validation_0-logloss:0.64631
# [111]	validation_0-logloss:0.64595
# [112]	validation_0-logloss:0.64557
# [113]	validation_0-logloss:0.64519
# [114]	validation_0-logloss:0.64481
# [115]	validation_0-logloss:0.64445
# [116]	validation_0-logloss:0.64407
# [117]	validation_0-logloss:0.64369
# [118]	validation_0-logloss:0.64332
# [119]	validation_0-logloss:0.64295
# [120]	validation_0-logloss:0.64258
# [121]	validation_0-logloss:0.64221
# [122]	validation_0-logloss:0.64184
# [123]	validation_0-logloss:0.64147
# [124]	validation_0-logloss:0.64110
# [125]	validation_0-logloss:0.64074
# [126]	validation_0-logloss:0.64036
# [127]	validation_0-logloss:0.64001
# [128]	validation_0-logloss:0.63963
# [129]	validation_0-logloss:0.63928
# [130]	validation_0-logloss:0.63891
# [131]	validation_0-logloss:0.63855
# [132]	validation_0-logloss:0.63818
# [133]	validation_0-logloss:0.63783
# [134]	validation_0-logloss:0.63746
# [135]	validation_0-logloss:0.63711
# [136]	validation_0-logloss:0.63675
# [137]	validation_0-logloss:0.63639
# [138]	validation_0-logloss:0.63604
# [139]	validation_0-logloss:0.63568
# [140]	validation_0-logloss:0.63532
# [141]	validation_0-logloss:0.63497
# [142]	validation_0-logloss:0.63462
# [143]	validation_0-logloss:0.63426
# [144]	validation_0-logloss:0.63390
# [145]	validation_0-logloss:0.63355
# [146]	validation_0-logloss:0.63320
# [147]	validation_0-logloss:0.63283
# [148]	validation_0-logloss:0.63249
# [149]	validation_0-logloss:0.63213
# [150]	validation_0-logloss:0.63178
# [151]	validation_0-logloss:0.63143
# [152]	validation_0-logloss:0.63109
# [153]	validation_0-logloss:0.63072
# [154]	validation_0-logloss:0.63038
# [155]	validation_0-logloss:0.63003
# [156]	validation_0-logloss:0.62968
# [157]	validation_0-logloss:0.62933
# [158]	validation_0-logloss:0.62900
# [159]	validation_0-logloss:0.62864
# [160]	validation_0-logloss:0.62830
# [161]	validation_0-logloss:0.62796
# [162]	validation_0-logloss:0.62761
# [163]	validation_0-logloss:0.62726
# [164]	validation_0-logloss:0.62693
# [165]	validation_0-logloss:0.62657
# [166]	validation_0-logloss:0.62624
# [167]	validation_0-logloss:0.62589
# [168]	validation_0-logloss:0.62555
# [169]	validation_0-logloss:0.62520
# [170]	validation_0-logloss:0.62487
# [171]	validation_0-logloss:0.62451
# [172]	validation_0-logloss:0.62418
# [173]	validation_0-logloss:0.62383
# [174]	validation_0-logloss:0.62349
# [175]	validation_0-logloss:0.62315
# [176]	validation_0-logloss:0.62282
# [177]	validation_0-logloss:0.62246
# [178]	validation_0-logloss:0.62214
# [179]	validation_0-logloss:0.62180
# [180]	validation_0-logloss:0.62147
# [181]	validation_0-logloss:0.62112
# [182]	validation_0-logloss:0.62079
# [183]	validation_0-logloss:0.62046
# [184]	validation_0-logloss:0.62011
# [185]	validation_0-logloss:0.61979
# [186]	validation_0-logloss:0.61945
# [187]	validation_0-logloss:0.61912
# [188]	validation_0-logloss:0.61878
# [189]	validation_0-logloss:0.61846
# [190]	validation_0-logloss:0.61811
# [191]	validation_0-logloss:0.61779
# [192]	validation_0-logloss:0.61745
# [193]	validation_0-logloss:0.61713
# [194]	validation_0-logloss:0.61680
# [195]	validation_0-logloss:0.61648
# [196]	validation_0-logloss:0.61613
# [197]	validation_0-logloss:0.61581
# [198]	validation_0-logloss:0.61548
# [199]	validation_0-logloss:0.61515
# [200]	validation_0-logloss:0.61483
# [201]	validation_0-logloss:0.61451
# [202]	validation_0-logloss:0.61417
# [203]	validation_0-logloss:0.61386
# [204]	validation_0-logloss:0.61353
# [205]	validation_0-logloss:0.61321
# [206]	validation_0-logloss:0.61288
# [207]	validation_0-logloss:0.61257
# [208]	validation_0-logloss:0.61223
# [209]	validation_0-logloss:0.61192
# [210]	validation_0-logloss:0.61160
# [211]	validation_0-logloss:0.61130
# [212]	validation_0-logloss:0.61096
# [213]	validation_0-logloss:0.61065
# [214]	validation_0-logloss:0.61033
# [215]	validation_0-logloss:0.61001
# [216]	validation_0-logloss:0.60969
# [217]	validation_0-logloss:0.60938
# [218]	validation_0-logloss:0.60905
# [219]	validation_0-logloss:0.60875
# [220]	validation_0-logloss:0.60843
# [221]	validation_0-logloss:0.60812
# [222]	validation_0-logloss:0.60780
# [223]	validation_0-logloss:0.60750
# [224]	validation_0-logloss:0.60717
# [225]	validation_0-logloss:0.60687
# [226]	validation_0-logloss:0.60655
# [227]	validation_0-logloss:0.60624
# [228]	validation_0-logloss:0.60594
# [229]	validation_0-logloss:0.60564
# [230]	validation_0-logloss:0.60531
# [231]	validation_0-logloss:0.60501
# [232]	validation_0-logloss:0.60470
# [233]	validation_0-logloss:0.60439
# [234]	validation_0-logloss:0.60408
# [235]	validation_0-logloss:0.60379
# [236]	validation_0-logloss:0.60347
# [237]	validation_0-logloss:0.60318
# [238]	validation_0-logloss:0.60287
# [239]	validation_0-logloss:0.60257
# [240]	validation_0-logloss:0.60226
# [241]	validation_0-logloss:0.60196
# [242]	validation_0-logloss:0.60165
# [243]	validation_0-logloss:0.60136
# [244]	validation_0-logloss:0.60106
# [245]	validation_0-logloss:0.60076
# [246]	validation_0-logloss:0.60045
# [247]	validation_0-logloss:0.60016
# [248]	validation_0-logloss:0.59986
# [249]	validation_0-logloss:0.59956
# [250]	validation_0-logloss:0.59927
# [251]	validation_0-logloss:0.59897
# [252]	validation_0-logloss:0.59866
# [253]	validation_0-logloss:0.59837
# [254]	validation_0-logloss:0.59808
# [255]	validation_0-logloss:0.59778
# [256]	validation_0-logloss:0.59749
# [257]	validation_0-logloss:0.59720
# [258]	validation_0-logloss:0.59690
# [259]	validation_0-logloss:0.59661
# [260]	validation_0-logloss:0.59632
# [261]	validation_0-logloss:0.59602
# [262]	validation_0-logloss:0.59573
# [263]	validation_0-logloss:0.59545
# [264]	validation_0-logloss:0.59515
# [265]	validation_0-logloss:0.59486
# [266]	validation_0-logloss:0.59458
# [267]	validation_0-logloss:0.59429
# [268]	validation_0-logloss:0.59400
# [269]	validation_0-logloss:0.59372
# [270]	validation_0-logloss:0.59342
# [271]	validation_0-logloss:0.59314
# [272]	validation_0-logloss:0.59285
# [273]	validation_0-logloss:0.59257
# [274]	validation_0-logloss:0.59228
# [275]	validation_0-logloss:0.59200
# [276]	validation_0-logloss:0.59172
# [277]	validation_0-logloss:0.59143
# [278]	validation_0-logloss:0.59115
# [279]	validation_0-logloss:0.59087
# [280]	validation_0-logloss:0.59058
# [281]	validation_0-logloss:0.59030
# [282]	validation_0-logloss:0.59003
# [283]	validation_0-logloss:0.58974
# [284]	validation_0-logloss:0.58946
# [285]	validation_0-logloss:0.58919
# [286]	validation_0-logloss:0.58890
# [287]	validation_0-logloss:0.58863
# [288]	validation_0-logloss:0.58835
# [289]	validation_0-logloss:0.58807
# [290]	validation_0-logloss:0.58779
# [291]	validation_0-logloss:0.58752
# [292]	validation_0-logloss:0.58724
# [293]	validation_0-logloss:0.58697
# [294]	validation_0-logloss:0.58670
# [295]	validation_0-logloss:0.58643
# [296]	validation_0-logloss:0.58615
# [297]	validation_0-logloss:0.58588
# [298]	validation_0-logloss:0.58561
# [299]	validation_0-logloss:0.58533
# [300]	validation_0-logloss:0.58506
# [301]	validation_0-logloss:0.58479
# [302]	validation_0-logloss:0.58452
# [303]	validation_0-logloss:0.58425
# [304]	validation_0-logloss:0.58398
# [305]	validation_0-logloss:0.58371
# [306]	validation_0-logloss:0.58344
# [307]	validation_0-logloss:0.58318
# [308]	validation_0-logloss:0.58290
# [309]	validation_0-logloss:0.58264
# [310]	validation_0-logloss:0.58237
# [311]	validation_0-logloss:0.58212
# [312]	validation_0-logloss:0.58184
# [313]	validation_0-logloss:0.58158
# [314]	validation_0-logloss:0.58132
# [315]	validation_0-logloss:0.58105
# [316]	validation_0-logloss:0.58078
# [317]	validation_0-logloss:0.58053
# [318]	validation_0-logloss:0.58025
# [319]	validation_0-logloss:0.58000
# [320]	validation_0-logloss:0.57974
# [321]	validation_0-logloss:0.57947
# [322]	validation_0-logloss:0.57921
# [323]	validation_0-logloss:0.57896
# [324]	validation_0-logloss:0.57869
# [325]	validation_0-logloss:0.57844
# [326]	validation_0-logloss:0.57817
# [327]	validation_0-logloss:0.57791
# [328]	validation_0-logloss:0.57765
# [329]	validation_0-logloss:0.57741
# [330]	validation_0-logloss:0.57715
# [331]	validation_0-logloss:0.57689
# [332]	validation_0-logloss:0.57663
# [333]	validation_0-logloss:0.57638
# [334]	validation_0-logloss:0.57611
# [335]	validation_0-logloss:0.57587
# [336]	validation_0-logloss:0.57561
# [337]	validation_0-logloss:0.57535
# [338]	validation_0-logloss:0.57510
# [339]	validation_0-logloss:0.57486
# [340]	validation_0-logloss:0.57459
# [341]	validation_0-logloss:0.57435
# [342]	validation_0-logloss:0.57410
# [343]	validation_0-logloss:0.57384
# [344]	validation_0-logloss:0.57359
# [345]	validation_0-logloss:0.57335
# [346]	validation_0-logloss:0.57309
# [347]	validation_0-logloss:0.57284
# [348]	validation_0-logloss:0.57259
# [349]	validation_0-logloss:0.57235
# [350]	validation_0-logloss:0.57209
# [351]	validation_0-logloss:0.57185
# [352]	validation_0-logloss:0.57161
# [353]	validation_0-logloss:0.57136
# [354]	validation_0-logloss:0.57111
# [355]	validation_0-logloss:0.57087
# [356]	validation_0-logloss:0.57061
# [357]	validation_0-logloss:0.57038
# [358]	validation_0-logloss:0.57013
# [359]	validation_0-logloss:0.56988
# [360]	validation_0-logloss:0.56964
# [361]	validation_0-logloss:0.56940
# [362]	validation_0-logloss:0.56916
# [363]	validation_0-logloss:0.56891
# [364]	validation_0-logloss:0.56867
# [365]	validation_0-logloss:0.56843
# [366]	validation_0-logloss:0.56819
# [367]	validation_0-logloss:0.56795
# [368]	validation_0-logloss:0.56771
# [369]	validation_0-logloss:0.56746
# [370]	validation_0-logloss:0.56722
# [371]	validation_0-logloss:0.56698
# [372]	validation_0-logloss:0.56675
# [373]	validation_0-logloss:0.56651
# [374]	validation_0-logloss:0.56627
# [375]	validation_0-logloss:0.56603
# [376]	validation_0-logloss:0.56579
# [377]	validation_0-logloss:0.56556
# [378]	validation_0-logloss:0.56532
# [379]	validation_0-logloss:0.56508
# [380]	validation_0-logloss:0.56485
# [381]	validation_0-logloss:0.56461
# [382]	validation_0-logloss:0.56438
# [383]	validation_0-logloss:0.56414
# [384]	validation_0-logloss:0.56391
# [385]	validation_0-logloss:0.56367
# [386]	validation_0-logloss:0.56344
# [387]	validation_0-logloss:0.56321
# [388]	validation_0-logloss:0.56298
# [389]	validation_0-logloss:0.56275
# [390]	validation_0-logloss:0.56251
# [391]	validation_0-logloss:0.56228
# [392]	validation_0-logloss:0.56205
# [393]	validation_0-logloss:0.56182
# [394]	validation_0-logloss:0.56159
# [395]	validation_0-logloss:0.56136
# [396]	validation_0-logloss:0.56113
# [397]	validation_0-logloss:0.56090
# [398]	validation_0-logloss:0.56068
# [399]	validation_0-logloss:0.56045
# [400]	validation_0-logloss:0.56022
# [401]	validation_0-logloss:0.56000
# [402]	validation_0-logloss:0.55977
# [403]	validation_0-logloss:0.55954
# [404]	validation_0-logloss:0.55931
# [405]	validation_0-logloss:0.55909
# [406]	validation_0-logloss:0.55887
# [407]	validation_0-logloss:0.55864
# [408]	validation_0-logloss:0.55842
# [409]	validation_0-logloss:0.55820
# [410]	validation_0-logloss:0.55797
# [411]	validation_0-logloss:0.55775
# [412]	validation_0-logloss:0.55753
# [413]	validation_0-logloss:0.55730
# [414]	validation_0-logloss:0.55708
# [415]	validation_0-logloss:0.55686
# [416]	validation_0-logloss:0.55664
# [417]	validation_0-logloss:0.55642
# [418]	validation_0-logloss:0.55620
# [419]	validation_0-logloss:0.55598
# [420]	validation_0-logloss:0.55576
# [421]	validation_0-logloss:0.55555
# [422]	validation_0-logloss:0.55532
# [423]	validation_0-logloss:0.55511
# [424]	validation_0-logloss:0.55489
# [425]	validation_0-logloss:0.55467
# [426]	validation_0-logloss:0.55446
# [427]	validation_0-logloss:0.55424
# [428]	validation_0-logloss:0.55403
# [429]	validation_0-logloss:0.55381
# [430]	validation_0-logloss:0.55360
# [431]	validation_0-logloss:0.55338
# [432]	validation_0-logloss:0.55316
# [433]	validation_0-logloss:0.55294
# [434]	validation_0-logloss:0.55273
# [435]	validation_0-logloss:0.55251
# [436]	validation_0-logloss:0.55229
# [437]	validation_0-logloss:0.55207
# [438]	validation_0-logloss:0.55186
# [439]	validation_0-logloss:0.55164
# [440]	validation_0-logloss:0.55143
# [441]	validation_0-logloss:0.55121
# [442]	validation_0-logloss:0.55100
# [443]	validation_0-logloss:0.55078
# [444]	validation_0-logloss:0.55057
# [445]	validation_0-logloss:0.55036
# [446]	validation_0-logloss:0.55014
# [447]	validation_0-logloss:0.54993
# [448]	validation_0-logloss:0.54972
# [449]	validation_0-logloss:0.54951
# [450]	validation_0-logloss:0.54929
# [451]	validation_0-logloss:0.54908
# [452]	validation_0-logloss:0.54887
# [453]	validation_0-logloss:0.54866
# [454]	validation_0-logloss:0.54845
# [455]	validation_0-logloss:0.54824
# [456]	validation_0-logloss:0.54803
# [457]	validation_0-logloss:0.54782
# [458]	validation_0-logloss:0.54762
# [459]	validation_0-logloss:0.54741
# [460]	validation_0-logloss:0.54720
# [461]	validation_0-logloss:0.54699
# [462]	validation_0-logloss:0.54679
# [463]	validation_0-logloss:0.54659
# [464]	validation_0-logloss:0.54638
# [465]	validation_0-logloss:0.54617
# [466]	validation_0-logloss:0.54597
# [467]	validation_0-logloss:0.54576
# [468]	validation_0-logloss:0.54556
# [469]	validation_0-logloss:0.54535
# [470]	validation_0-logloss:0.54515
# [471]	validation_0-logloss:0.54495
# [472]	validation_0-logloss:0.54475
# [473]	validation_0-logloss:0.54454
# [474]	validation_0-logloss:0.54434
# [475]	validation_0-logloss:0.54414
# [476]	validation_0-logloss:0.54394
# [477]	validation_0-logloss:0.54374
# [478]	validation_0-logloss:0.54354
# [479]	validation_0-logloss:0.54334
# [480]	validation_0-logloss:0.54314
# [481]	validation_0-logloss:0.54294
# [482]	validation_0-logloss:0.54275
# [483]	validation_0-logloss:0.54255
# [484]	validation_0-logloss:0.54235
# [485]	validation_0-logloss:0.54215
# [486]	validation_0-logloss:0.54195
# [487]	validation_0-logloss:0.54176
# [488]	validation_0-logloss:0.54156
# [489]	validation_0-logloss:0.54136
# [490]	validation_0-logloss:0.54117
# [491]	validation_0-logloss:0.54097
# [492]	validation_0-logloss:0.54078
# [493]	validation_0-logloss:0.54058
# [494]	validation_0-logloss:0.54039
# [495]	validation_0-logloss:0.54020
# [496]	validation_0-logloss:0.54001
# [497]	validation_0-logloss:0.53982
# [498]	validation_0-logloss:0.53963
# [499]	validation_0-logloss:0.53944
# [500]	validation_0-logloss:0.53925
# [501]	validation_0-logloss:0.53906
# [502]	validation_0-logloss:0.53887
# [503]	validation_0-logloss:0.53868
# [504]	validation_0-logloss:0.53849
# [505]	validation_0-logloss:0.53831
# [506]	validation_0-logloss:0.53812
# [507]	validation_0-logloss:0.53793
# [508]	validation_0-logloss:0.53774
# [509]	validation_0-logloss:0.53756
# [510]	validation_0-logloss:0.53737
# [511]	validation_0-logloss:0.53719
# [512]	validation_0-logloss:0.53700
# [513]	validation_0-logloss:0.53682
# [514]	validation_0-logloss:0.53663
# [515]	validation_0-logloss:0.53645
# [516]	validation_0-logloss:0.53626
# [517]	validation_0-logloss:0.53608
# [518]	validation_0-logloss:0.53589
# [519]	validation_0-logloss:0.53571
# [520]	validation_0-logloss:0.53553
# [521]	validation_0-logloss:0.53535
# [522]	validation_0-logloss:0.53516
# [523]	validation_0-logloss:0.53498
# [524]	validation_0-logloss:0.53480
# [525]	validation_0-logloss:0.53462
# [526]	validation_0-logloss:0.53444
# [527]	validation_0-logloss:0.53426
# [528]	validation_0-logloss:0.53407
# [529]	validation_0-logloss:0.53390
# [530]	validation_0-logloss:0.53372
# [531]	validation_0-logloss:0.53354
# [532]	validation_0-logloss:0.53336
# [533]	validation_0-logloss:0.53318
# [534]	validation_0-logloss:0.53300
# [535]	validation_0-logloss:0.53282
# [536]	validation_0-logloss:0.53264
# [537]	validation_0-logloss:0.53246
# [538]	validation_0-logloss:0.53229
# [539]	validation_0-logloss:0.53211
# [540]	validation_0-logloss:0.53193
# [541]	validation_0-logloss:0.53175
# [542]	validation_0-logloss:0.53158
# [543]	validation_0-logloss:0.53140
# [544]	validation_0-logloss:0.53122
# [545]	validation_0-logloss:0.53105
# [546]	validation_0-logloss:0.53087
# [547]	validation_0-logloss:0.53070
# [548]	validation_0-logloss:0.53052
# [549]	validation_0-logloss:0.53035
# [550]	validation_0-logloss:0.53017
# [551]	validation_0-logloss:0.53000
# [552]	validation_0-logloss:0.52982
# [553]	validation_0-logloss:0.52965
# [554]	validation_0-logloss:0.52948
# [555]	validation_0-logloss:0.52930
# [556]	validation_0-logloss:0.52913
# [557]	validation_0-logloss:0.52895
# [558]	validation_0-logloss:0.52879
# [559]	validation_0-logloss:0.52861
# [560]	validation_0-logloss:0.52844
# [561]	validation_0-logloss:0.52827
# [562]	validation_0-logloss:0.52810
# [563]	validation_0-logloss:0.52792
# [564]	validation_0-logloss:0.52775
# [565]	validation_0-logloss:0.52759
# [566]	validation_0-logloss:0.52742
# [567]	validation_0-logloss:0.52725
# [568]	validation_0-logloss:0.52708
# [569]	validation_0-logloss:0.52691
# [570]	validation_0-logloss:0.52674
# [571]	validation_0-logloss:0.52658
# [572]	validation_0-logloss:0.52641
# [573]	validation_0-logloss:0.52624
# [574]	validation_0-logloss:0.52607
# [575]	validation_0-logloss:0.52591
# [576]	validation_0-logloss:0.52575
# [577]	validation_0-logloss:0.52558
# [578]	validation_0-logloss:0.52541
# [579]	validation_0-logloss:0.52525
# [580]	validation_0-logloss:0.52508
# [581]	validation_0-logloss:0.52491
# [582]	validation_0-logloss:0.52475
# [583]	validation_0-logloss:0.52459
# [584]	validation_0-logloss:0.52442
# [585]	validation_0-logloss:0.52426
# [586]	validation_0-logloss:0.52409
# [587]	validation_0-logloss:0.52393
# [588]	validation_0-logloss:0.52377
# [589]	validation_0-logloss:0.52360
# [590]	validation_0-logloss:0.52344
# [591]	validation_0-logloss:0.52328
# [592]	validation_0-logloss:0.52312
# [593]	validation_0-logloss:0.52295
# [594]	validation_0-logloss:0.52279
# [595]	validation_0-logloss:0.52263
# [596]	validation_0-logloss:0.52247
# [597]	validation_0-logloss:0.52231
# [598]	validation_0-logloss:0.52215
# [599]	validation_0-logloss:0.52199
# [600]	validation_0-logloss:0.52183
# [601]	validation_0-logloss:0.52166
# [602]	validation_0-logloss:0.52150
# [603]	validation_0-logloss:0.52134
# [604]	validation_0-logloss:0.52119
# [605]	validation_0-logloss:0.52103
# [606]	validation_0-logloss:0.52087
# [607]	validation_0-logloss:0.52071
# [608]	validation_0-logloss:0.52055
# [609]	validation_0-logloss:0.52039
# [610]	validation_0-logloss:0.52024
# [611]	validation_0-logloss:0.52008
# [612]	validation_0-logloss:0.51992
# [613]	validation_0-logloss:0.51977
# [614]	validation_0-logloss:0.51961
# [615]	validation_0-logloss:0.51946
# [616]	validation_0-logloss:0.51930
# [617]	validation_0-logloss:0.51914
# [618]	validation_0-logloss:0.51898
# [619]	validation_0-logloss:0.51883
# [620]	validation_0-logloss:0.51868
# [621]	validation_0-logloss:0.51853
# [622]	validation_0-logloss:0.51837
# [623]	validation_0-logloss:0.51821
# [624]	validation_0-logloss:0.51806
# [625]	validation_0-logloss:0.51791
# [626]	validation_0-logloss:0.51776
# [627]	validation_0-logloss:0.51760
# [628]	validation_0-logloss:0.51745
# [629]	validation_0-logloss:0.51729
# [630]	validation_0-logloss:0.51714
# [631]	validation_0-logloss:0.51699
# [632]	validation_0-logloss:0.51684
# [633]	validation_0-logloss:0.51669
# [634]	validation_0-logloss:0.51653
# [635]	validation_0-logloss:0.51638
# [636]	validation_0-logloss:0.51623
# [637]	validation_0-logloss:0.51608
# [638]	validation_0-logloss:0.51593
# [639]	validation_0-logloss:0.51578
# [640]	validation_0-logloss:0.51562
# [641]	validation_0-logloss:0.51548
# [642]	validation_0-logloss:0.51533
# [643]	validation_0-logloss:0.51518
# [644]	validation_0-logloss:0.51503
# [645]	validation_0-logloss:0.51488
# [646]	validation_0-logloss:0.51473
# [647]	validation_0-logloss:0.51459
# [648]	validation_0-logloss:0.51444
# [649]	validation_0-logloss:0.51429
# [650]	validation_0-logloss:0.51414
# [651]	validation_0-logloss:0.51400
# [652]	validation_0-logloss:0.51385
# [653]	validation_0-logloss:0.51370
# [654]	validation_0-logloss:0.51355
# [655]	validation_0-logloss:0.51341
# [656]	validation_0-logloss:0.51326
# [657]	validation_0-logloss:0.51311
# [658]	validation_0-logloss:0.51296
# [659]	validation_0-logloss:0.51282
# [660]	validation_0-logloss:0.51268
# [661]	validation_0-logloss:0.51253
# [662]	validation_0-logloss:0.51238
# [663]	validation_0-logloss:0.51224
# [664]	validation_0-logloss:0.51209
# [665]	validation_0-logloss:0.51195
# [666]	validation_0-logloss:0.51181
# [667]	validation_0-logloss:0.51166
# [668]	validation_0-logloss:0.51152
# [669]	validation_0-logloss:0.51138
# [670]	validation_0-logloss:0.51123
# [671]	validation_0-logloss:0.51109
# [672]	validation_0-logloss:0.51094
# [673]	validation_0-logloss:0.51080
# [674]	validation_0-logloss:0.51066
# [675]	validation_0-logloss:0.51052
# [676]	validation_0-logloss:0.51038
# [677]	validation_0-logloss:0.51023
# [678]	validation_0-logloss:0.51009
# [679]	validation_0-logloss:0.50995
# [680]	validation_0-logloss:0.50981
# [681]	validation_0-logloss:0.50967
# [682]	validation_0-logloss:0.50953
# [683]	validation_0-logloss:0.50939
# [684]	validation_0-logloss:0.50924
# [685]	validation_0-logloss:0.50909
# [686]	validation_0-logloss:0.50895
# [687]	validation_0-logloss:0.50881
# [688]	validation_0-logloss:0.50867
# [689]	validation_0-logloss:0.50853
# [690]	validation_0-logloss:0.50838
# [691]	validation_0-logloss:0.50825
# [692]	validation_0-logloss:0.50811
# [693]	validation_0-logloss:0.50796
# [694]	validation_0-logloss:0.50782
# [695]	validation_0-logloss:0.50768
# [696]	validation_0-logloss:0.50754
# [697]	validation_0-logloss:0.50739
# [698]	validation_0-logloss:0.50725
# [699]	validation_0-logloss:0.50710
# [700]	validation_0-logloss:0.50695
# [701]	validation_0-logloss:0.50681
# [702]	validation_0-logloss:0.50666
# [703]	validation_0-logloss:0.50652
# [704]	validation_0-logloss:0.50637
# [705]	validation_0-logloss:0.50622
# [706]	validation_0-logloss:0.50608
# [707]	validation_0-logloss:0.50593
# [708]	validation_0-logloss:0.50579
# [709]	validation_0-logloss:0.50564
# [710]	validation_0-logloss:0.50549
# [711]	validation_0-logloss:0.50535
# [712]	validation_0-logloss:0.50521
# [713]	validation_0-logloss:0.50506
# [714]	validation_0-logloss:0.50492
# [715]	validation_0-logloss:0.50477
# [716]	validation_0-logloss:0.50463
# [717]	validation_0-logloss:0.50449
# [718]	validation_0-logloss:0.50434
# [719]	validation_0-logloss:0.50420
# [720]	validation_0-logloss:0.50406
# [721]	validation_0-logloss:0.50392
# [722]	validation_0-logloss:0.50377
# [723]	validation_0-logloss:0.50364
# [724]	validation_0-logloss:0.50349
# [725]	validation_0-logloss:0.50335
# [726]	validation_0-logloss:0.50321
# [727]	validation_0-logloss:0.50306
# [728]	validation_0-logloss:0.50293
# [729]	validation_0-logloss:0.50279
# [730]	validation_0-logloss:0.50265
# [731]	validation_0-logloss:0.50251
# [732]	validation_0-logloss:0.50236
# [733]	validation_0-logloss:0.50222
# [734]	validation_0-logloss:0.50209
# [735]	validation_0-logloss:0.50195
# [736]	validation_0-logloss:0.50181
# [737]	validation_0-logloss:0.50167
# [738]	validation_0-logloss:0.50153
# [739]	validation_0-logloss:0.50139
# [740]	validation_0-logloss:0.50125
# [741]	validation_0-logloss:0.50112
# [742]	validation_0-logloss:0.50098
# [743]	validation_0-logloss:0.50084
# [744]	validation_0-logloss:0.50070
# [745]	validation_0-logloss:0.50057
# [746]	validation_0-logloss:0.50043
# [747]	validation_0-logloss:0.50030
# [748]	validation_0-logloss:0.50016
# [749]	validation_0-logloss:0.50002
# [750]	validation_0-logloss:0.49989
# [751]	validation_0-logloss:0.49975
# [752]	validation_0-logloss:0.49962
# [753]	validation_0-logloss:0.49948
# [754]	validation_0-logloss:0.49935
# [755]	validation_0-logloss:0.49921
# [756]	validation_0-logloss:0.49908
# [757]	validation_0-logloss:0.49894
# [758]	validation_0-logloss:0.49881
# [759]	validation_0-logloss:0.49868
# [760]	validation_0-logloss:0.49854
# [761]	validation_0-logloss:0.49841
# [762]	validation_0-logloss:0.49828
# [763]	validation_0-logloss:0.49815
# [764]	validation_0-logloss:0.49802
# [765]	validation_0-logloss:0.49788
# [766]	validation_0-logloss:0.49776
# [767]	validation_0-logloss:0.49762
# [768]	validation_0-logloss:0.49750
# [769]	validation_0-logloss:0.49737
# [770]	validation_0-logloss:0.49724
# [771]	validation_0-logloss:0.49711
# [772]	validation_0-logloss:0.49698
# [773]	validation_0-logloss:0.49686
# [774]	validation_0-logloss:0.49673
# [775]	validation_0-logloss:0.49660
# [776]	validation_0-logloss:0.49647
# [777]	validation_0-logloss:0.49635
# [778]	validation_0-logloss:0.49622
# [779]	validation_0-logloss:0.49610
# [780]	validation_0-logloss:0.49597
# [781]	validation_0-logloss:0.49584
# [782]	validation_0-logloss:0.49572
# [783]	validation_0-logloss:0.49559
# [784]	validation_0-logloss:0.49547
# [785]	validation_0-logloss:0.49534
# [786]	validation_0-logloss:0.49522
# [787]	validation_0-logloss:0.49509
# [788]	validation_0-logloss:0.49497
# [789]	validation_0-logloss:0.49485
# [790]	validation_0-logloss:0.49473
# [791]	validation_0-logloss:0.49460
# [792]	validation_0-logloss:0.49448
# [793]	validation_0-logloss:0.49435
# [794]	validation_0-logloss:0.49423
# [795]	validation_0-logloss:0.49412
# [796]	validation_0-logloss:0.49399
# [797]	validation_0-logloss:0.49387
# [798]	validation_0-logloss:0.49375
# [799]	validation_0-logloss:0.49363
# [800]	validation_0-logloss:0.49350
# [801]	validation_0-logloss:0.49339
# [802]	validation_0-logloss:0.49327
# [803]	validation_0-logloss:0.49314
# [804]	validation_0-logloss:0.49302
# [805]	validation_0-logloss:0.49291
# [806]	validation_0-logloss:0.49278
# [807]	validation_0-logloss:0.49266
# [808]	validation_0-logloss:0.49255
# [809]	validation_0-logloss:0.49242
# [810]	validation_0-logloss:0.49230
# [811]	validation_0-logloss:0.49218
# [812]	validation_0-logloss:0.49207
# [813]	validation_0-logloss:0.49195
# [814]	validation_0-logloss:0.49183
# [815]	validation_0-logloss:0.49172
# [816]	validation_0-logloss:0.49160
# [817]	validation_0-logloss:0.49148
# [818]	validation_0-logloss:0.49136
# [819]	validation_0-logloss:0.49124
# [820]	validation_0-logloss:0.49112
# [821]	validation_0-logloss:0.49101
# [822]	validation_0-logloss:0.49089
# [823]	validation_0-logloss:0.49078
# [824]	validation_0-logloss:0.49066
# [825]	validation_0-logloss:0.49055
# [826]	validation_0-logloss:0.49043
# [827]	validation_0-logloss:0.49032
# [828]	validation_0-logloss:0.49020
# [829]	validation_0-logloss:0.49009
# [830]	validation_0-logloss:0.48997
# [831]	validation_0-logloss:0.48987
# [832]	validation_0-logloss:0.48975
# [833]	validation_0-logloss:0.48964
# [834]	validation_0-logloss:0.48952
# [835]	validation_0-logloss:0.48941
# [836]	validation_0-logloss:0.48930
# [837]	validation_0-logloss:0.48918
# [838]	validation_0-logloss:0.48907
# [839]	validation_0-logloss:0.48897
# [840]	validation_0-logloss:0.48885
# [841]	validation_0-logloss:0.48874
# [842]	validation_0-logloss:0.48863
# [843]	validation_0-logloss:0.48852
# [844]	validation_0-logloss:0.48841
# [845]	validation_0-logloss:0.48830
# [846]	validation_0-logloss:0.48819
# [847]	validation_0-logloss:0.48809
# [848]	validation_0-logloss:0.48797
# [849]	validation_0-logloss:0.48786
# [850]	validation_0-logloss:0.48775
# [851]	validation_0-logloss:0.48764
# [852]	validation_0-logloss:0.48754
# [853]	validation_0-logloss:0.48743
# [854]	validation_0-logloss:0.48732
# [855]	validation_0-logloss:0.48721
# [856]	validation_0-logloss:0.48710
# [857]	validation_0-logloss:0.48700
# [858]	validation_0-logloss:0.48689
# [859]	validation_0-logloss:0.48677
# [860]	validation_0-logloss:0.48667
# [861]	validation_0-logloss:0.48656
# [862]	validation_0-logloss:0.48646
# [863]	validation_0-logloss:0.48635
# [864]	validation_0-logloss:0.48624
# [865]	validation_0-logloss:0.48614
# [866]	validation_0-logloss:0.48603
# [867]	validation_0-logloss:0.48593
# [868]	validation_0-logloss:0.48582
# [869]	validation_0-logloss:0.48571
# [870]	validation_0-logloss:0.48561
# [871]	validation_0-logloss:0.48551
# [872]	validation_0-logloss:0.48540
# [873]	validation_0-logloss:0.48530
# [874]	validation_0-logloss:0.48520
# [875]	validation_0-logloss:0.48509
# [876]	validation_0-logloss:0.48500
# [877]	validation_0-logloss:0.48489
# [878]	validation_0-logloss:0.48478
# [879]	validation_0-logloss:0.48468
# [880]	validation_0-logloss:0.48458
# [881]	validation_0-logloss:0.48448
# [882]	validation_0-logloss:0.48437
# [883]	validation_0-logloss:0.48427
# [884]	validation_0-logloss:0.48417
# [885]	validation_0-logloss:0.48406
# [886]	validation_0-logloss:0.48396
# [887]	validation_0-logloss:0.48386
# [888]	validation_0-logloss:0.48376
# [889]	validation_0-logloss:0.48366
# [890]	validation_0-logloss:0.48356
# [891]	validation_0-logloss:0.48346
# [892]	validation_0-logloss:0.48336
# [893]	validation_0-logloss:0.48325
# [894]	validation_0-logloss:0.48315
# [895]	validation_0-logloss:0.48306
# [896]	validation_0-logloss:0.48295
# [897]	validation_0-logloss:0.48285
# [898]	validation_0-logloss:0.48275
# [899]	validation_0-logloss:0.48265
# [900]	validation_0-logloss:0.48255
# [901]	validation_0-logloss:0.48245
# [902]	validation_0-logloss:0.48235
# [903]	validation_0-logloss:0.48225
# [904]	validation_0-logloss:0.48216
# [905]	validation_0-logloss:0.48206
# [906]	validation_0-logloss:0.48196
# [907]	validation_0-logloss:0.48187
# [908]	validation_0-logloss:0.48177
# [909]	validation_0-logloss:0.48168
# [910]	validation_0-logloss:0.48158
# [911]	validation_0-logloss:0.48149
# [912]	validation_0-logloss:0.48140
# [913]	validation_0-logloss:0.48130
# [914]	validation_0-logloss:0.48121
# [915]	validation_0-logloss:0.48111
# [916]	validation_0-logloss:0.48102
# [917]	validation_0-logloss:0.48093
# [918]	validation_0-logloss:0.48083
# [919]	validation_0-logloss:0.48074
# [920]	validation_0-logloss:0.48065
# [921]	validation_0-logloss:0.48055
# [922]	validation_0-logloss:0.48046
# [923]	validation_0-logloss:0.48037
# [924]	validation_0-logloss:0.48027
# [925]	validation_0-logloss:0.48018
# [926]	validation_0-logloss:0.48008
# [927]	validation_0-logloss:0.47998
# [928]	validation_0-logloss:0.47989
# [929]	validation_0-logloss:0.47980
# [930]	validation_0-logloss:0.47971
# [931]	validation_0-logloss:0.47962
# [932]	validation_0-logloss:0.47953
# [933]	validation_0-logloss:0.47943
# [934]	validation_0-logloss:0.47934
# [935]	validation_0-logloss:0.47924
# [936]	validation_0-logloss:0.47915
# [937]	validation_0-logloss:0.47906
# [938]	validation_0-logloss:0.47897
# [939]	validation_0-logloss:0.47887
# [940]	validation_0-logloss:0.47878
# [941]	validation_0-logloss:0.47869
# [942]	validation_0-logloss:0.47860
# [943]	validation_0-logloss:0.47851
# [944]	validation_0-logloss:0.47842
# [945]	validation_0-logloss:0.47833
# [946]	validation_0-logloss:0.47824
# [947]	validation_0-logloss:0.47815
# [948]	validation_0-logloss:0.47806
# [949]	validation_0-logloss:0.47797
# [950]	validation_0-logloss:0.47788
# [951]	validation_0-logloss:0.47779
# [952]	validation_0-logloss:0.47770
# [953]	validation_0-logloss:0.47762
# [954]	validation_0-logloss:0.47753
# [955]	validation_0-logloss:0.47744
# [956]	validation_0-logloss:0.47735
# [957]	validation_0-logloss:0.47727
# [958]	validation_0-logloss:0.47718
# [959]	validation_0-logloss:0.47709
# [960]	validation_0-logloss:0.47701
# [961]	validation_0-logloss:0.47692
# [962]	validation_0-logloss:0.47683
# [963]	validation_0-logloss:0.47674
# [964]	validation_0-logloss:0.47665
# [965]	validation_0-logloss:0.47657
# [966]	validation_0-logloss:0.47648
# [967]	validation_0-logloss:0.47639
# [968]	validation_0-logloss:0.47630
# [969]	validation_0-logloss:0.47621
# [970]	validation_0-logloss:0.47612
# [971]	validation_0-logloss:0.47604
# [972]	validation_0-logloss:0.47595
# [973]	validation_0-logloss:0.47586
# [974]	validation_0-logloss:0.47578
# [975]	validation_0-logloss:0.47569
# [976]	validation_0-logloss:0.47561
# [977]	validation_0-logloss:0.47553
# [978]	validation_0-logloss:0.47544
# [979]	validation_0-logloss:0.47535
# [980]	validation_0-logloss:0.47527
# [981]	validation_0-logloss:0.47518
# [982]	validation_0-logloss:0.47510
# [983]	validation_0-logloss:0.47501
# [984]	validation_0-logloss:0.47493
# [985]	validation_0-logloss:0.47484
# [986]	validation_0-logloss:0.47476
# [987]	validation_0-logloss:0.47468
# [988]	validation_0-logloss:0.47459
# [989]	validation_0-logloss:0.47450
# [990]	validation_0-logloss:0.47442
# [991]	validation_0-logloss:0.47434
# [992]	validation_0-logloss:0.47426
# [993]	validation_0-logloss:0.47418
# [994]	validation_0-logloss:0.47409
# [995]	validation_0-logloss:0.47400
# [996]	validation_0-logloss:0.47393
# [997]	validation_0-logloss:0.47384
# [998]	validation_0-logloss:0.47375
# [999]	validation_0-logloss:0.47368
# [0]	validation_0-logloss:0.69270
# [1]	validation_0-logloss:0.69225
# [2]	validation_0-logloss:0.69180
# [3]	validation_0-logloss:0.69135
# [4]	validation_0-logloss:0.69091
# [5]	validation_0-logloss:0.69046
# [6]	validation_0-logloss:0.69002
# [7]	validation_0-logloss:0.68957
# [8]	validation_0-logloss:0.68913
# [9]	validation_0-logloss:0.68869
# [10]	validation_0-logloss:0.68825
# [11]	validation_0-logloss:0.68781
# [12]	validation_0-logloss:0.68737
# [13]	validation_0-logloss:0.68693
# [14]	validation_0-logloss:0.68649
# [15]	validation_0-logloss:0.68606
# [16]	validation_0-logloss:0.68562
# [17]	validation_0-logloss:0.68519
# [18]	validation_0-logloss:0.68476
# [19]	validation_0-logloss:0.68432
# [20]	validation_0-logloss:0.68389
# [21]	validation_0-logloss:0.68346
# [22]	validation_0-logloss:0.68303
# [23]	validation_0-logloss:0.68260
# [24]	validation_0-logloss:0.68217
# [25]	validation_0-logloss:0.68175
# [26]	validation_0-logloss:0.68132
# [27]	validation_0-logloss:0.68090
# [28]	validation_0-logloss:0.68047
# [29]	validation_0-logloss:0.68005
# [30]	validation_0-logloss:0.67963
# [31]	validation_0-logloss:0.67920
# [32]	validation_0-logloss:0.67878
# [33]	validation_0-logloss:0.67836
# [34]	validation_0-logloss:0.67795
# [35]	validation_0-logloss:0.67753
# [36]	validation_0-logloss:0.67711
# [37]	validation_0-logloss:0.67669
# [38]	validation_0-logloss:0.67628
# [39]	validation_0-logloss:0.67586
# [40]	validation_0-logloss:0.67545
# [41]	validation_0-logloss:0.67504
# [42]	validation_0-logloss:0.67463
# [43]	validation_0-logloss:0.67421
# [44]	validation_0-logloss:0.67380
# [45]	validation_0-logloss:0.67339
# [46]	validation_0-logloss:0.67299
# [47]	validation_0-logloss:0.67258
# [48]	validation_0-logloss:0.67217
# [49]	validation_0-logloss:0.67176
# [50]	validation_0-logloss:0.67136
# [51]	validation_0-logloss:0.67095
# [52]	validation_0-logloss:0.67055
# [53]	validation_0-logloss:0.67015
# [54]	validation_0-logloss:0.66975
# [55]	validation_0-logloss:0.66935
# [56]	validation_0-logloss:0.66895
# [57]	validation_0-logloss:0.66855
# [58]	validation_0-logloss:0.66815
# [59]	validation_0-logloss:0.66775
# [60]	validation_0-logloss:0.66736
# [61]	validation_0-logloss:0.66696
# [62]	validation_0-logloss:0.66656
# [63]	validation_0-logloss:0.66617
# [64]	validation_0-logloss:0.66578
# [65]	validation_0-logloss:0.66539
# [66]	validation_0-logloss:0.66500
# [67]	validation_0-logloss:0.66462
# [68]	validation_0-logloss:0.66424
# [69]	validation_0-logloss:0.66385
# [70]	validation_0-logloss:0.66348
# [71]	validation_0-logloss:0.66309
# [72]	validation_0-logloss:0.66271
# [73]	validation_0-logloss:0.66234
# [74]	validation_0-logloss:0.66195
# [75]	validation_0-logloss:0.66158
# [76]	validation_0-logloss:0.66119
# [77]	validation_0-logloss:0.66082
# [78]	validation_0-logloss:0.66044
# [79]	validation_0-logloss:0.66006
# [80]	validation_0-logloss:0.65968
# [81]	validation_0-logloss:0.65931
# [82]	validation_0-logloss:0.65892
# [83]	validation_0-logloss:0.65855
# [84]	validation_0-logloss:0.65816
# [85]	validation_0-logloss:0.65780
# [86]	validation_0-logloss:0.65742
# [87]	validation_0-logloss:0.65705
# [88]	validation_0-logloss:0.65668
# [89]	validation_0-logloss:0.65630
# [90]	validation_0-logloss:0.65594
# [91]	validation_0-logloss:0.65557
# [92]	validation_0-logloss:0.65520
# [93]	validation_0-logloss:0.65483
# [94]	validation_0-logloss:0.65446
# [95]	validation_0-logloss:0.65409
# [96]	validation_0-logloss:0.65372
# [97]	validation_0-logloss:0.65334
# [98]	validation_0-logloss:0.65297
# [99]	validation_0-logloss:0.65260
# [100]	validation_0-logloss:0.65224
# [101]	validation_0-logloss:0.65188
# [102]	validation_0-logloss:0.65150
# [103]	validation_0-logloss:0.65114
# [104]	validation_0-logloss:0.65076
# [105]	validation_0-logloss:0.65040
# [106]	validation_0-logloss:0.65004
# [107]	validation_0-logloss:0.64967
# [108]	validation_0-logloss:0.64932
# [109]	validation_0-logloss:0.64895
# [110]	validation_0-logloss:0.64859
# [111]	validation_0-logloss:0.64824
# [112]	validation_0-logloss:0.64786
# [113]	validation_0-logloss:0.64751
# [114]	validation_0-logloss:0.64715
# [115]	validation_0-logloss:0.64680
# [116]	validation_0-logloss:0.64644
# [117]	validation_0-logloss:0.64608
# [118]	validation_0-logloss:0.64572
# [119]	validation_0-logloss:0.64538
# [120]	validation_0-logloss:0.64501
# [121]	validation_0-logloss:0.64466
# [122]	validation_0-logloss:0.64431
# [123]	validation_0-logloss:0.64396
# [124]	validation_0-logloss:0.64361
# [125]	validation_0-logloss:0.64326
# [126]	validation_0-logloss:0.64290
# [127]	validation_0-logloss:0.64255
# [128]	validation_0-logloss:0.64221
# [129]	validation_0-logloss:0.64186
# [130]	validation_0-logloss:0.64151
# [131]	validation_0-logloss:0.64116
# [132]	validation_0-logloss:0.64081
# [133]	validation_0-logloss:0.64048
# [134]	validation_0-logloss:0.64014
# [135]	validation_0-logloss:0.63978
# [136]	validation_0-logloss:0.63945
# [137]	validation_0-logloss:0.63910
# [138]	validation_0-logloss:0.63876
# [139]	validation_0-logloss:0.63842
# [140]	validation_0-logloss:0.63808
# [141]	validation_0-logloss:0.63774
# [142]	validation_0-logloss:0.63740
# [143]	validation_0-logloss:0.63706
# [144]	validation_0-logloss:0.63673
# [145]	validation_0-logloss:0.63639
# [146]	validation_0-logloss:0.63606
# [147]	validation_0-logloss:0.63573
# [148]	validation_0-logloss:0.63539
# [149]	validation_0-logloss:0.63506
# [150]	validation_0-logloss:0.63473
# [151]	validation_0-logloss:0.63439
# [152]	validation_0-logloss:0.63406
# [153]	validation_0-logloss:0.63374
# [154]	validation_0-logloss:0.63341
# [155]	validation_0-logloss:0.63308
# [156]	validation_0-logloss:0.63275
# [157]	validation_0-logloss:0.63242
# [158]	validation_0-logloss:0.63209
# [159]	validation_0-logloss:0.63177
# [160]	validation_0-logloss:0.63144
# [161]	validation_0-logloss:0.63112
# [162]	validation_0-logloss:0.63080
# [163]	validation_0-logloss:0.63047
# [164]	validation_0-logloss:0.63015
# [165]	validation_0-logloss:0.62982
# [166]	validation_0-logloss:0.62950
# [167]	validation_0-logloss:0.62919
# [168]	validation_0-logloss:0.62886
# [169]	validation_0-logloss:0.62854
# [170]	validation_0-logloss:0.62822
# [171]	validation_0-logloss:0.62791
# [172]	validation_0-logloss:0.62759
# [173]	validation_0-logloss:0.62727
# [174]	validation_0-logloss:0.62695
# [175]	validation_0-logloss:0.62663
# [176]	validation_0-logloss:0.62631
# [177]	validation_0-logloss:0.62600
# [178]	validation_0-logloss:0.62569
# [179]	validation_0-logloss:0.62538
# [180]	validation_0-logloss:0.62506
# [181]	validation_0-logloss:0.62475
# [182]	validation_0-logloss:0.62444
# [183]	validation_0-logloss:0.62412
# [184]	validation_0-logloss:0.62382
# [185]	validation_0-logloss:0.62351
# [186]	validation_0-logloss:0.62320
# [187]	validation_0-logloss:0.62289
# [188]	validation_0-logloss:0.62257
# [189]	validation_0-logloss:0.62227
# [190]	validation_0-logloss:0.62196
# [191]	validation_0-logloss:0.62165
# [192]	validation_0-logloss:0.62135
# [193]	validation_0-logloss:0.62104
# [194]	validation_0-logloss:0.62074
# [195]	validation_0-logloss:0.62044
# [196]	validation_0-logloss:0.62014
# [197]	validation_0-logloss:0.61983
# [198]	validation_0-logloss:0.61953
# [199]	validation_0-logloss:0.61922
# [200]	validation_0-logloss:0.61893
# [201]	validation_0-logloss:0.61863
# [202]	validation_0-logloss:0.61833
# [203]	validation_0-logloss:0.61802
# [204]	validation_0-logloss:0.61773
# [205]	validation_0-logloss:0.61743
# [206]	validation_0-logloss:0.61713
# [207]	validation_0-logloss:0.61683
# [208]	validation_0-logloss:0.61653
# [209]	validation_0-logloss:0.61624
# [210]	validation_0-logloss:0.61595
# [211]	validation_0-logloss:0.61564
# [212]	validation_0-logloss:0.61535
# [213]	validation_0-logloss:0.61506
# [214]	validation_0-logloss:0.61476
# [215]	validation_0-logloss:0.61448
# [216]	validation_0-logloss:0.61418
# [217]	validation_0-logloss:0.61389
# [218]	validation_0-logloss:0.61360
# [219]	validation_0-logloss:0.61330
# [220]	validation_0-logloss:0.61302
# [221]	validation_0-logloss:0.61273
# [222]	validation_0-logloss:0.61244
# [223]	validation_0-logloss:0.61215
# [224]	validation_0-logloss:0.61186
# [225]	validation_0-logloss:0.61157
# [226]	validation_0-logloss:0.61129
# [227]	validation_0-logloss:0.61101
# [228]	validation_0-logloss:0.61072
# [229]	validation_0-logloss:0.61043
# [230]	validation_0-logloss:0.61014
# [231]	validation_0-logloss:0.60986
# [232]	validation_0-logloss:0.60958
# [233]	validation_0-logloss:0.60930
# [234]	validation_0-logloss:0.60901
# [235]	validation_0-logloss:0.60874
# [236]	validation_0-logloss:0.60845
# [237]	validation_0-logloss:0.60817
# [238]	validation_0-logloss:0.60789
# [239]	validation_0-logloss:0.60760
# [240]	validation_0-logloss:0.60733
# [241]	validation_0-logloss:0.60705
# [242]	validation_0-logloss:0.60677
# [243]	validation_0-logloss:0.60650
# [244]	validation_0-logloss:0.60623
# [245]	validation_0-logloss:0.60594
# [246]	validation_0-logloss:0.60567
# [247]	validation_0-logloss:0.60539
# [248]	validation_0-logloss:0.60512
# [249]	validation_0-logloss:0.60485
# [250]	validation_0-logloss:0.60457
# [251]	validation_0-logloss:0.60430
# [252]	validation_0-logloss:0.60402
# [253]	validation_0-logloss:0.60375
# [254]	validation_0-logloss:0.60348
# [255]	validation_0-logloss:0.60320
# [256]	validation_0-logloss:0.60293
# [257]	validation_0-logloss:0.60267
# [258]	validation_0-logloss:0.60239
# [259]	validation_0-logloss:0.60213
# [260]	validation_0-logloss:0.60186
# [261]	validation_0-logloss:0.60159
# [262]	validation_0-logloss:0.60132
# [263]	validation_0-logloss:0.60106
# [264]	validation_0-logloss:0.60079
# [265]	validation_0-logloss:0.60052
# [266]	validation_0-logloss:0.60026
# [267]	validation_0-logloss:0.60000
# [268]	validation_0-logloss:0.59972
# [269]	validation_0-logloss:0.59947
# [270]	validation_0-logloss:0.59920
# [271]	validation_0-logloss:0.59893
# [272]	validation_0-logloss:0.59867
# [273]	validation_0-logloss:0.59840
# [274]	validation_0-logloss:0.59815
# [275]	validation_0-logloss:0.59789
# [276]	validation_0-logloss:0.59762
# [277]	validation_0-logloss:0.59737
# [278]	validation_0-logloss:0.59711
# [279]	validation_0-logloss:0.59686
# [280]	validation_0-logloss:0.59660
# [281]	validation_0-logloss:0.59635
# [282]	validation_0-logloss:0.59610
# [283]	validation_0-logloss:0.59584
# [284]	validation_0-logloss:0.59558
# [285]	validation_0-logloss:0.59533
# [286]	validation_0-logloss:0.59508
# [287]	validation_0-logloss:0.59483
# [288]	validation_0-logloss:0.59458
# [289]	validation_0-logloss:0.59432
# [290]	validation_0-logloss:0.59408
# [291]	validation_0-logloss:0.59383
# [292]	validation_0-logloss:0.59358
# [293]	validation_0-logloss:0.59333
# [294]	validation_0-logloss:0.59307
# [295]	validation_0-logloss:0.59282
# [296]	validation_0-logloss:0.59258
# [297]	validation_0-logloss:0.59233
# [298]	validation_0-logloss:0.59208
# [299]	validation_0-logloss:0.59183
# [300]	validation_0-logloss:0.59159
# [301]	validation_0-logloss:0.59134
# [302]	validation_0-logloss:0.59110
# [303]	validation_0-logloss:0.59085
# [304]	validation_0-logloss:0.59061
# [305]	validation_0-logloss:0.59036
# [306]	validation_0-logloss:0.59012
# [307]	validation_0-logloss:0.58987
# [308]	validation_0-logloss:0.58962
# [309]	validation_0-logloss:0.58938
# [310]	validation_0-logloss:0.58914
# [311]	validation_0-logloss:0.58889
# [312]	validation_0-logloss:0.58865
# [313]	validation_0-logloss:0.58840
# [314]	validation_0-logloss:0.58816
# [315]	validation_0-logloss:0.58791
# [316]	validation_0-logloss:0.58768
# [317]	validation_0-logloss:0.58744
# [318]	validation_0-logloss:0.58720
# [319]	validation_0-logloss:0.58696
# [320]	validation_0-logloss:0.58672
# [321]	validation_0-logloss:0.58648
# [322]	validation_0-logloss:0.58625
# [323]	validation_0-logloss:0.58600
# [324]	validation_0-logloss:0.58576
# [325]	validation_0-logloss:0.58553
# [326]	validation_0-logloss:0.58530
# [327]	validation_0-logloss:0.58506
# [328]	validation_0-logloss:0.58483
# [329]	validation_0-logloss:0.58460
# [330]	validation_0-logloss:0.58437
# [331]	validation_0-logloss:0.58414
# [332]	validation_0-logloss:0.58392
# [333]	validation_0-logloss:0.58367
# [334]	validation_0-logloss:0.58344
# [335]	validation_0-logloss:0.58322
# [336]	validation_0-logloss:0.58297
# [337]	validation_0-logloss:0.58274
# [338]	validation_0-logloss:0.58252
# [339]	validation_0-logloss:0.58229
# [340]	validation_0-logloss:0.58204
# [341]	validation_0-logloss:0.58182
# [342]	validation_0-logloss:0.58159
# [343]	validation_0-logloss:0.58136
# [344]	validation_0-logloss:0.58113
# [345]	validation_0-logloss:0.58090
# [346]	validation_0-logloss:0.58066
# [347]	validation_0-logloss:0.58045
# [348]	validation_0-logloss:0.58022
# [349]	validation_0-logloss:0.58001
# [350]	validation_0-logloss:0.57978
# [351]	validation_0-logloss:0.57954
# [352]	validation_0-logloss:0.57928
# [353]	validation_0-logloss:0.57903
# [354]	validation_0-logloss:0.57878
# [355]	validation_0-logloss:0.57853
# [356]	validation_0-logloss:0.57827
# [357]	validation_0-logloss:0.57803
# [358]	validation_0-logloss:0.57777
# [359]	validation_0-logloss:0.57752
# [360]	validation_0-logloss:0.57727
# [361]	validation_0-logloss:0.57703
# [362]	validation_0-logloss:0.57678
# [363]	validation_0-logloss:0.57653
# [364]	validation_0-logloss:0.57628
# [365]	validation_0-logloss:0.57604
# [366]	validation_0-logloss:0.57579
# [367]	validation_0-logloss:0.57555
# [368]	validation_0-logloss:0.57530
# [369]	validation_0-logloss:0.57505
# [370]	validation_0-logloss:0.57481
# [371]	validation_0-logloss:0.57456
# [372]	validation_0-logloss:0.57432
# [373]	validation_0-logloss:0.57408
# [374]	validation_0-logloss:0.57384
# [375]	validation_0-logloss:0.57360
# ...
# [543]	validation_0-logloss:0.53204
# [544]	validation_0-logloss:0.53185
# [545]	validation_0-logloss:0.53167
# [546]	validation_0-logloss:0.53150
# [547]	validation_0-logloss:0.53131
# [548]	validation_0-logloss:0.53114
# [549]	validation_0-logloss:0.53097
# [550]	validation_0-logloss:0.53079
# [551]	validation_0-logloss:0.53063
# [552]	validation_0-logloss:0.53044
# [553]	validation_0-logloss:0.53028
# [554]	validation_0-logloss:0.53011
# [555]	validation_0-logloss:0.52995
# [556]	validation_0-logloss:0.52978
# [557]	validation_0-logloss:0.52962
# [558]	validation_0-logloss:0.52947
# [559]	validation_0-logloss:0.52929
# [560]	validation_0-logloss:0.52914
# [561]	validation_0-logloss:0.52897
# [562]	validation_0-logloss:0.52881
# [563]	validation_0-logloss:0.52866
# [564]	validation_0-logloss:0.52849
# [565]	validation_0-logloss:0.52834
# [566]	validation_0-logloss:0.52818
# [567]	validation_0-logloss:0.52801
# [568]	validation_0-logloss:0.52786
# [569]	validation_0-logloss:0.52768
# [570]	validation_0-logloss:0.52753
# [571]	validation_0-logloss:0.52737
# [572]	validation_0-logloss:0.52721
# [573]	validation_0-logloss:0.52705
# [574]	validation_0-logloss:0.52689
# [575]	validation_0-logloss:0.52673
# [576]	validation_0-logloss:0.52658
# [577]	validation_0-logloss:0.52642
# [578]	validation_0-logloss:0.52627
# [579]	validation_0-logloss:0.52612
# [580]	validation_0-logloss:0.52595
# [581]	validation_0-logloss:0.52580
# [582]	validation_0-logloss:0.52564
# [583]	validation_0-logloss:0.52549
# [584]	validation_0-logloss:0.52534
# [585]	validation_0-logloss:0.52517
# [586]	validation_0-logloss:0.52503
# [587]	validation_0-logloss:0.52488
# [588]	validation_0-logloss:0.52472
# [589]	validation_0-logloss:0.52457
# [590]	validation_0-logloss:0.52441
# [591]	validation_0-logloss:0.52426
# [592]	validation_0-logloss:0.52411
# [593]	validation_0-logloss:0.52395
# [594]	validation_0-logloss:0.52380
# [595]	validation_0-logloss:0.52366
# [596]	validation_0-logloss:0.52350
# [597]	validation_0-logloss:0.52335
# [598]	validation_0-logloss:0.52319
# [599]	validation_0-logloss:0.52305
# [600]	validation_0-logloss:0.52290
# [601]	validation_0-logloss:0.52274
# [602]	validation_0-logloss:0.52260
# [603]	validation_0-logloss:0.52245
# [604]	validation_0-logloss:0.52229
# [605]	validation_0-logloss:0.52215
# [606]	validation_0-logloss:0.52198
# [607]	validation_0-logloss:0.52184
# [608]	validation_0-logloss:0.52170
# [609]	validation_0-logloss:0.52154
# [610]	validation_0-logloss:0.52138
# [611]	validation_0-logloss:0.52121
# [612]	validation_0-logloss:0.52105
# [613]	validation_0-logloss:0.52089
# [614]	validation_0-logloss:0.52073
# [615]	validation_0-logloss:0.52056
# [616]	validation_0-logloss:0.52040
# [617]	validation_0-logloss:0.52024
# [618]	validation_0-logloss:0.52007
# [619]	validation_0-logloss:0.51991
# [620]	validation_0-logloss:0.51975
# [621]	validation_0-logloss:0.51959
# [622]	validation_0-logloss:0.51943
# [623]	validation_0-logloss:0.51927
# [624]	validation_0-logloss:0.51911
# [625]	validation_0-logloss:0.51895
# [626]	validation_0-logloss:0.51879
# [627]	validation_0-logloss:0.51863
# [628]	validation_0-logloss:0.51847
# [629]	validation_0-logloss:0.51831
# [630]	validation_0-logloss:0.51815
# [631]	validation_0-logloss:0.51799
# [632]	validation_0-logloss:0.51784
# [633]	validation_0-logloss:0.51767
# [634]	validation_0-logloss:0.51752
# [635]	validation_0-logloss:0.51736
# [636]	validation_0-logloss:0.51721
# [637]	validation_0-logloss:0.51705
# [638]	validation_0-logloss:0.51690
# [639]	validation_0-logloss:0.51674
# [640]	validation_0-logloss:0.51658
# [641]	validation_0-logloss:0.51643
# [642]	validation_0-logloss:0.51626
# [643]	validation_0-logloss:0.51611
# [644]	validation_0-logloss:0.51596
# [645]	validation_0-logloss:0.51581
# [646]	validation_0-logloss:0.51565
# [647]	validation_0-logloss:0.51550
# [648]	validation_0-logloss:0.51534
# [649]	validation_0-logloss:0.51518
# [650]	validation_0-logloss:0.51504
# [651]	validation_0-logloss:0.51487
# [652]	validation_0-logloss:0.51472
# [653]	validation_0-logloss:0.51456
# [654]	validation_0-logloss:0.51441
# [655]	validation_0-logloss:0.51424
# [656]	validation_0-logloss:0.51409
# [657]	validation_0-logloss:0.51393
# [658]	validation_0-logloss:0.51378
# [659]	validation_0-logloss:0.51362
# [660]	validation_0-logloss:0.51346
# [661]	validation_0-logloss:0.51331
# [662]	validation_0-logloss:0.51315
# [663]	validation_0-logloss:0.51300
# [664]	validation_0-logloss:0.51284
# [665]	validation_0-logloss:0.51269
# [666]	validation_0-logloss:0.51254
# [667]	validation_0-logloss:0.51239
# [668]	validation_0-logloss:0.51223
# [669]	validation_0-logloss:0.51208
# [670]	validation_0-logloss:0.51193
# [671]	validation_0-logloss:0.51177
# [672]	validation_0-logloss:0.51162
# [673]	validation_0-logloss:0.51147
# [674]	validation_0-logloss:0.51132
# [675]	validation_0-logloss:0.51116
# [676]	validation_0-logloss:0.51102
# [677]	validation_0-logloss:0.51086
# [678]	validation_0-logloss:0.51071
# [679]	validation_0-logloss:0.51056
# [680]	validation_0-logloss:0.51041
# [681]	validation_0-logloss:0.51026
# [682]	validation_0-logloss:0.51011
# [683]	validation_0-logloss:0.50997
# [684]	validation_0-logloss:0.50981
# [685]	validation_0-logloss:0.50967
# [686]	validation_0-logloss:0.50952
# [687]	validation_0-logloss:0.50937
# [688]	validation_0-logloss:0.50922
# [689]	validation_0-logloss:0.50908
# [690]	validation_0-logloss:0.50892
# [691]	validation_0-logloss:0.50877
# [692]	validation_0-logloss:0.50864
# [693]	validation_0-logloss:0.50848
# [694]	validation_0-logloss:0.50834
# [695]	validation_0-logloss:0.50819
# [696]	validation_0-logloss:0.50805
# [697]	validation_0-logloss:0.50790
# [698]	validation_0-logloss:0.50776
# [699]	validation_0-logloss:0.50761
# [700]	validation_0-logloss:0.50746
# [701]	validation_0-logloss:0.50732
# [702]	validation_0-logloss:0.50717
# [703]	validation_0-logloss:0.50703
# [704]	validation_0-logloss:0.50688
# [705]	validation_0-logloss:0.50675
# [706]	validation_0-logloss:0.50660
# [707]	validation_0-logloss:0.50646
# [708]	validation_0-logloss:0.50632
# [709]	validation_0-logloss:0.50618
# [710]	validation_0-logloss:0.50603
# [711]	validation_0-logloss:0.50589
# [712]	validation_0-logloss:0.50575
# [713]	validation_0-logloss:0.50560
# [714]	validation_0-logloss:0.50547
# [715]	validation_0-logloss:0.50532
# [716]	validation_0-logloss:0.50519
# [717]	validation_0-logloss:0.50504
# [718]	validation_0-logloss:0.50491
# [719]	validation_0-logloss:0.50476
# [720]	validation_0-logloss:0.50462
# [721]	validation_0-logloss:0.50449
# [722]	validation_0-logloss:0.50434
# [723]	validation_0-logloss:0.50421
# [724]	validation_0-logloss:0.50407
# [725]	validation_0-logloss:0.50393
# [726]	validation_0-logloss:0.50379
# [727]	validation_0-logloss:0.50365
# [728]	validation_0-logloss:0.50352
# [729]	validation_0-logloss:0.50338
# [730]	validation_0-logloss:0.50324
# [731]	validation_0-logloss:0.50309
# [732]	validation_0-logloss:0.50297
# [733]	validation_0-logloss:0.50282
# [734]	validation_0-logloss:0.50269
# [735]	validation_0-logloss:0.50255
# [736]	validation_0-logloss:0.50242
# [737]	validation_0-logloss:0.50228
# [738]	validation_0-logloss:0.50215
# [739]	validation_0-logloss:0.50201
# [740]	validation_0-logloss:0.50188
# [741]	validation_0-logloss:0.50174
# [742]	validation_0-logloss:0.50160
# [743]	validation_0-logloss:0.50147
# [744]	validation_0-logloss:0.50132
# [745]	validation_0-logloss:0.50120
# [746]	validation_0-logloss:0.50106
# [747]	validation_0-logloss:0.50093
# [748]	validation_0-logloss:0.50079
# [749]	validation_0-logloss:0.50067
# [750]	validation_0-logloss:0.50052
# [751]	validation_0-logloss:0.50039
# [752]	validation_0-logloss:0.50026
# [753]	validation_0-logloss:0.50012
# [754]	validation_0-logloss:0.50000
# [755]	validation_0-logloss:0.49986
# [756]	validation_0-logloss:0.49973
# [757]	validation_0-logloss:0.49960
# [758]	validation_0-logloss:0.49947
# [759]	validation_0-logloss:0.49934
# [760]	validation_0-logloss:0.49921
# [761]	validation_0-logloss:0.49908
# [762]	validation_0-logloss:0.49894
# [763]	validation_0-logloss:0.49881
# [764]	validation_0-logloss:0.49868
# [765]	validation_0-logloss:0.49855
# [766]	validation_0-logloss:0.49842
# [767]	validation_0-logloss:0.49830
# [768]	validation_0-logloss:0.49816
# [769]	validation_0-logloss:0.49804
# [770]	validation_0-logloss:0.49791
# [771]	validation_0-logloss:0.49777
# [772]	validation_0-logloss:0.49765
# [773]	validation_0-logloss:0.49752
# [774]	validation_0-logloss:0.49740
# [775]	validation_0-logloss:0.49727
# [776]	validation_0-logloss:0.49714
# [777]	validation_0-logloss:0.49701
# [778]	validation_0-logloss:0.49689
# [779]	validation_0-logloss:0.49676
# [780]	validation_0-logloss:0.49664
# [781]	validation_0-logloss:0.49651
# [782]	validation_0-logloss:0.49638
# [783]	validation_0-logloss:0.49626
# [784]	validation_0-logloss:0.49612
# [785]	validation_0-logloss:0.49601
# [786]	validation_0-logloss:0.49588
# [787]	validation_0-logloss:0.49575
# [788]	validation_0-logloss:0.49563
# [789]	validation_0-logloss:0.49550
# [790]	validation_0-logloss:0.49537
# [791]	validation_0-logloss:0.49524
# [792]	validation_0-logloss:0.49511
# [793]	validation_0-logloss:0.49498
# [794]	validation_0-logloss:0.49485
# [795]	validation_0-logloss:0.49472
# [796]	validation_0-logloss:0.49460
# [797]	validation_0-logloss:0.49447
# [798]	validation_0-logloss:0.49435
# [799]	validation_0-logloss:0.49422
# [800]	validation_0-logloss:0.49409
# [801]	validation_0-logloss:0.49396
# [802]	validation_0-logloss:0.49383
# [803]	validation_0-logloss:0.49370
# [804]	validation_0-logloss:0.49358
# [805]	validation_0-logloss:0.49345
# [806]	validation_0-logloss:0.49333
# [807]	validation_0-logloss:0.49320
# [808]	validation_0-logloss:0.49307
# [809]	validation_0-logloss:0.49296
# [810]	validation_0-logloss:0.49283
# [811]	validation_0-logloss:0.49270
# [812]	validation_0-logloss:0.49258
# [813]	validation_0-logloss:0.49245
# [814]	validation_0-logloss:0.49234
# [815]	validation_0-logloss:0.49221
# [816]	validation_0-logloss:0.49208
# [817]	validation_0-logloss:0.49196
# [818]	validation_0-logloss:0.49184
# [819]	validation_0-logloss:0.49171
# [820]	validation_0-logloss:0.49159
# [821]	validation_0-logloss:0.49146
# [822]	validation_0-logloss:0.49135
# [823]	validation_0-logloss:0.49123
# [824]	validation_0-logloss:0.49110
# [825]	validation_0-logloss:0.49099
# [826]	validation_0-logloss:0.49086
# [827]	validation_0-logloss:0.49073
# [828]	validation_0-logloss:0.49062
# [829]	validation_0-logloss:0.49049
# [830]	validation_0-logloss:0.49038
# [831]	validation_0-logloss:0.49025
# [832]	validation_0-logloss:0.49013
# [833]	validation_0-logloss:0.49001
# [834]	validation_0-logloss:0.48989
# [835]	validation_0-logloss:0.48978
# [836]	validation_0-logloss:0.48966
# [837]	validation_0-logloss:0.48954
# [838]	validation_0-logloss:0.48942
# [839]	validation_0-logloss:0.48931
# [840]	validation_0-logloss:0.48918
# [841]	validation_0-logloss:0.48908
# [842]	validation_0-logloss:0.48895
# [843]	validation_0-logloss:0.48884
# [844]	validation_0-logloss:0.48873
# [845]	validation_0-logloss:0.48860
# [846]	validation_0-logloss:0.48850
# [847]	validation_0-logloss:0.48837
# [848]	validation_0-logloss:0.48826
# [849]	validation_0-logloss:0.48815
# [850]	validation_0-logloss:0.48802
# [851]	validation_0-logloss:0.48792
# [852]	validation_0-logloss:0.48780
# [853]	validation_0-logloss:0.48768
# [854]	validation_0-logloss:0.48757
# [855]	validation_0-logloss:0.48746
# [856]	validation_0-logloss:0.48734
# [857]	validation_0-logloss:0.48723
# [858]	validation_0-logloss:0.48711
# [859]	validation_0-logloss:0.48701
# [860]	validation_0-logloss:0.48689
# [861]	validation_0-logloss:0.48678
# [862]	validation_0-logloss:0.48667
# [863]	validation_0-logloss:0.48655
# [864]	validation_0-logloss:0.48643
# [865]	validation_0-logloss:0.48633
# [866]	validation_0-logloss:0.48621
# [867]	validation_0-logloss:0.48611
# [868]	validation_0-logloss:0.48599
# [869]	validation_0-logloss:0.48588
# [870]	validation_0-logloss:0.48578
# [871]	validation_0-logloss:0.48566
# [872]	validation_0-logloss:0.48555
# [873]	validation_0-logloss:0.48544
# [874]	validation_0-logloss:0.48534
# [875]	validation_0-logloss:0.48524
# [876]	validation_0-logloss:0.48512
# [877]	validation_0-logloss:0.48501
# [878]	validation_0-logloss:0.48491
# [879]	validation_0-logloss:0.48480
# [880]	validation_0-logloss:0.48470
# [881]	validation_0-logloss:0.48459
# [882]	validation_0-logloss:0.48448
# [883]	validation_0-logloss:0.48438
# [884]	validation_0-logloss:0.48427
# [885]	validation_0-logloss:0.48415
# [886]	validation_0-logloss:0.48405
# [887]	validation_0-logloss:0.48396
# [888]	validation_0-logloss:0.48386
# [889]	validation_0-logloss:0.48375
# [890]	validation_0-logloss:0.48364
# [891]	validation_0-logloss:0.48354
# [892]	validation_0-logloss:0.48343
# [893]	validation_0-logloss:0.48332
# [894]	validation_0-logloss:0.48322
# [895]	validation_0-logloss:0.48312
# [896]	validation_0-logloss:0.48302
# [897]	validation_0-logloss:0.48291
# [898]	validation_0-logloss:0.48281
# [899]	validation_0-logloss:0.48270
# [900]	validation_0-logloss:0.48260
# [901]	validation_0-logloss:0.48249
# [902]	validation_0-logloss:0.48240
# [903]	validation_0-logloss:0.48229
# [904]	validation_0-logloss:0.48220
# [905]	validation_0-logloss:0.48209
# [906]	validation_0-logloss:0.48198
# [907]	validation_0-logloss:0.48188
# [908]	validation_0-logloss:0.48178
# [909]	validation_0-logloss:0.48168
# [910]	validation_0-logloss:0.48158
# [911]	validation_0-logloss:0.48147
# [912]	validation_0-logloss:0.48136
# [913]	validation_0-logloss:0.48126
# [914]	validation_0-logloss:0.48115
# [915]	validation_0-logloss:0.48106
# [916]	validation_0-logloss:0.48095
# [917]	validation_0-logloss:0.48084
# [918]	validation_0-logloss:0.48075
# [919]	validation_0-logloss:0.48064
# [920]	validation_0-logloss:0.48054
# [921]	validation_0-logloss:0.48043
# [922]	validation_0-logloss:0.48033
# [923]	validation_0-logloss:0.48023
# [924]	validation_0-logloss:0.48012
# [925]	validation_0-logloss:0.48002
# [926]	validation_0-logloss:0.47993
# [927]	validation_0-logloss:0.47983
# [928]	validation_0-logloss:0.47973
# [929]	validation_0-logloss:0.47962
# [930]	validation_0-logloss:0.47952
# [931]	validation_0-logloss:0.47942
# [932]	validation_0-logloss:0.47932
# [933]	validation_0-logloss:0.47922
# [934]	validation_0-logloss:0.47912
# [935]	validation_0-logloss:0.47902
# [936]	validation_0-logloss:0.47893
# [937]	validation_0-logloss:0.47883
# [938]	validation_0-logloss:0.47872
# [939]	validation_0-logloss:0.47863
# [940]	validation_0-logloss:0.47853
# [941]	validation_0-logloss:0.47842
# [942]	validation_0-logloss:0.47833
# [943]	validation_0-logloss:0.47823
# [944]	validation_0-logloss:0.47813
# [945]	validation_0-logloss:0.47803
# [946]	validation_0-logloss:0.47793
# [947]	validation_0-logloss:0.47784
# [948]	validation_0-logloss:0.47775
# [949]	validation_0-logloss:0.47764
# [950]	validation_0-logloss:0.47755
# [951]	validation_0-logloss:0.47745
# [952]	validation_0-logloss:0.47735
# [953]	validation_0-logloss:0.47726
# [954]	validation_0-logloss:0.47716
# [955]	validation_0-logloss:0.47707
# [956]	validation_0-logloss:0.47697
# [957]	validation_0-logloss:0.47688
# [958]	validation_0-logloss:0.47678
# [959]	validation_0-logloss:0.47668
# [960]	validation_0-logloss:0.47659
# [961]	validation_0-logloss:0.47650
# [962]	validation_0-logloss:0.47640
# [963]	validation_0-logloss:0.47631
# [964]	validation_0-logloss:0.47621
# [965]	validation_0-logloss:0.47612
# [966]	validation_0-logloss:0.47602
# [967]	validation_0-logloss:0.47593
# [968]	validation_0-logloss:0.47584
# [969]	validation_0-logloss:0.47575
# [970]	validation_0-logloss:0.47565
# [971]	validation_0-logloss:0.47556
# [972]	validation_0-logloss:0.47547
# [973]	validation_0-logloss:0.47537
# [974]	validation_0-logloss:0.47529
# [975]	validation_0-logloss:0.47519
# [976]	validation_0-logloss:0.47510
# [977]	validation_0-logloss:0.47501
# [978]	validation_0-logloss:0.47491
# [979]	validation_0-logloss:0.47482
# [980]	validation_0-logloss:0.47473
# [981]	validation_0-logloss:0.47463
# [982]	validation_0-logloss:0.47455
# [983]	validation_0-logloss:0.47446
# [984]	validation_0-logloss:0.47437
# [985]	validation_0-logloss:0.47428
# [986]	validation_0-logloss:0.47418
# [987]	validation_0-logloss:0.47410
# [988]	validation_0-logloss:0.47401
# [989]	validation_0-logloss:0.47393
# [990]	validation_0-logloss:0.47385
# [991]	validation_0-logloss:0.47376
# [992]	validation_0-logloss:0.47368
# [993]	validation_0-logloss:0.47359
# [994]	validation_0-logloss:0.47351
# [995]	validation_0-logloss:0.47343
# [996]	validation_0-logloss:0.47334
# [997]	validation_0-logloss:0.47327
# [998]	validation_0-logloss:0.47318
# [999]	validation_0-logloss:0.47309

# %% [markdown]
# XGB는 early stopping을 사용하기 위해 훈련 데이터의 일부를 검증 데이터로 분리했다.
# 그래서 best_estimator는 전체 훈련 데이터를 사용해서 학습하지 않았기 때문에 동일한 파라미터일지라도 전체 훈련데이터로 학습한 모델과 테스트 결과가 다르다.
# best_estimator를 전체 훈련데이터로 학습한다면 best_param으로 학습한 모델과 테스트 결과가 동일하다.

# %% [markdown]
# ## 테스트2
# 그리드서치의 best_estimator의 테스트 점수가 가장 높을까?
# => 테스트해본 결과는 다음과 같다.
#
# 1. 그리드서치의 best_estimator의 테스트 점수가 가장 좋다고 확신할 수 없다. 대체로 교차검증 점수의 평균이 best_estimator보다 조금 낮아도 표준편차가 작은 경우 테스트 성능이 좋은 경우가  많이 보인다.
# 2. early stopping이 필요한 알고리즘(ex XGB or NN etc.)은 그리드서치를 위해 별도의 검증 데이터가 필요하다. 전체 훈련 데이터를 사용하지 않기 때문에 성능이 떨어지므로 최적의 파라미터를  찾은 다음, 전체 데이터로 학습한 모델을 만들어야 한다.

# %%
from sklearn.metrics import roc_auc_score, accuracy_score

# %%
# logistic regresssion

print(roc_auc_score(sol.Survived, y_pred_best_estimator_lg))
print(roc_auc_score(sol.Survived, LogisticRegression(C=.1).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, LogisticRegression(C=.01).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, LogisticRegression(C=.001).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, LogisticRegression(C=.0001).fit(X_train, y_train).predict(X_test)))
# Out:
# 0.7467380720545278
# 0.7507059396299903
# 0.7246348588120739
# 0.626460564751704
# 0.5

# %%
# SVC

print(roc_auc_score(sol.Survived, y_pred_best_estimator_svm))
print(roc_auc_score(sol.Survived, SVC(C=.0001, gamma=.0001).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.0001, gamma=.001).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.0001, gamma=.01).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.0001, gamma=.1).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.0001, gamma=1).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.001, gamma=.0001).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.001, gamma=.001).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.001, gamma=.01).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.001, gamma=.1).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.001, gamma=1).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.01, gamma=.0001).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.01, gamma=.001).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.01, gamma=.01).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.01, gamma=.1).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.01, gamma=1).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.1, gamma=.0001).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.1, gamma=.001).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.1, gamma=.01).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.1, gamma=.1).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=.1, gamma=1).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=1, gamma=.0001).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=1, gamma=.001).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=1, gamma=.01).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=1, gamma=.1).fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, SVC(C=1, gamma=1).fit(X_train, y_train).predict(X_test)))
# Out:
# 0.765968841285297
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.7000000000000001
# 0.7556718597857839
# 0.5041626095423565
# 0.5
# 0.7101752677702045
# 0.7698149951314508
# 0.765968841285297
# 0.7313534566699124

# %%
# XGB

print(roc_auc_score(sol.Survived, y_pred_best_estimator_xgb))
print(roc_auc_score(sol.Survived, XGBClassifier(learning_rate=.001, n_estimators=1000, eval_metric='mlogloss').fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, XGBClassifier(learning_rate=.01, n_estimators=1000, eval_metric='mlogloss').fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, XGBClassifier(learning_rate=.1, n_estimators=1000, eval_metric='mlogloss').fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, XGBClassifier(learning_rate=1, n_estimators=1000, eval_metric='mlogloss').fit(X_train, y_train).predict(X_test)))
# Out:
# 0.7386075949367089
# 0.7559152872444012
# 0.7424537487828627
# 0.7194985394352482
# 0.7207400194741967

# %%
# XGB Early Stop

print(roc_auc_score(sol.Survived, y_pred_best_estimator_xgb))
print(roc_auc_score(sol.Survived, XGBClassifier(learning_rate=.001, n_estimators=1000, eval_metric='mlogloss').fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, XGBClassifier(learning_rate=.01, n_estimators=1000, eval_metric='mlogloss').fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, XGBClassifier(learning_rate=.1, n_estimators=1000, eval_metric='mlogloss').fit(X_train, y_train).predict(X_test)))
print(roc_auc_score(sol.Survived, XGBClassifier(learning_rate=1, n_estimators=1000, eval_metric='mlogloss').fit(X_train, y_train).predict(X_test)))
# Out:
# 0.7424537487828627
# 0.7559152872444012
# 0.7424537487828627
# 0.7194985394352482
# 0.7207400194741967

# %% [markdown]
# ## 결론
# 1. 그리드서치는 최적의 반복 횟수 or 측정기 개수도 탐색의 대상으로 잡기 때문에 early stopping을 사용하지 않는 것이 좋다. 과적합을 유발하지 않는 최적의 파라미터 조합을 찾는 것이 목적인데 early stop은 어떤 조합이던 상관없이 과적합이 발생하지 않도록 막아주기 때문이다.
# 2. 그리드서치의 최적의 파라미터 조합을 얻어냈다고해서 이 조합이 테스트셋에 대해서도 최적이라는 보장은 없다. 따라서 최적 조합의 상위 그룹들을 전반적으로 테스트해볼 필요가 있으며, 특히 교차검증 점수의 표준편차가 작은 조합일수록 테스트셋에서의 일반화 성능이 좋았다.
# 3. 그리드서치의 best_estimator는 fit에서 제공된 훈련데이터를 마지막에 학습한 모델이므로, best_params를 사용해서 별도의 모델을 생성하거나 best_estimator를 다시 전체 훈련 데이터로 학습할 필요가 없다.
